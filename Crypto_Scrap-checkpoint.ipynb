# %%
from selenium import webdriver
import time

# %%
import requests
from bs4 import BeautifulSoup

url = "https://coinmarketcap.com/fr/"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

elements = soup.find_all('tr', class_=lambda value: value and 'sc-' in value)

# %%
def get_elements_with_cursor_pointer(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')

    elements = soup.find_all('tr', style=lambda style: style and 'cursor:pointer' in style)
    return elements

# %%
cursor_pointer_elements = get_elements_with_cursor_pointer(url)

elements = cursor_pointer_elements + elements

# %%
filtered_elements = []
seen_markets = set()

for element in elements:
    crypto_name = element.find('a', class_='cmc-link').text.strip()

    if 'cursor:pointer' in element.get('style', ''):
        price = element.find_all('td')[3].text.strip()
        crypto_market = element.find_all('td')[-2].text.strip() 
    else:
        price = element.find_all('td')[-2].text.strip()
        crypto_market = element.find('a', class_='cmc-link')['href'].split('/')[-2].capitalize()

    if crypto_market not in seen_markets:
        filtered_elements.append((crypto_name, price, crypto_market))
        seen_markets.add(crypto_market)

# Afficher les éléments filtrés
for crypto_name, price, crypto_market in filtered_elements:
    print(crypto_name, price, crypto_market)
# Out:
# BitcoinBTC €64,834.19 19,665,712 BTC
# EthereumETH €3,307.45 120,073,215 ETH
# Tether USDtUSDT €0.9241 104,362,092,744 USDT
# BNBBNB €533.74 149,536,620 BNB
# SolanaSOL €172.58 444,306,679 SOL
# XRPXRP €0.5741 54,884,241,878 XRP
# USDCUSDC €0.9242 32,287,299,828 USDC
# DogecoinDOGE €0.1738 143,639,236,384 DOGE
# CardanoADA €0.6035 35,578,756,687 ADA
# AvalancheAVAX €50.25 377,416,536 AVAX
# Shiba InuSHIB $0.00 Shiba-inu
# ToncoinTON $5.04 Toncoin
# PolkadotDOT $9.59 Polkadot-new
# ChainlinkLINK $19.70 Chainlink
# TRONTRX $0.12 Tron
# PolygonMATIC $1.05 Polygon
# Bitcoin CashBCH $496.57 Bitcoin-cash
# Internet ComputerICP $19.48 Internet-computer
# NEAR ProtocolNEAR $7.73 Near-protocol
# UniswapUNI $12.48 Uniswap
# AptosAPT $18.22 Aptos
# LitecoinLTC $96.64 Litecoin
# UNUS SED LEOLEO $6.07 Unus-sed-leo
# DaiDAI $1.00 Multi-collateral-dai
# CosmosATOM $12.84 Cosmos
# StacksSTX $3.45 Stacks
# FilecoinFIL $9.36 Filecoin
# Ethereum ClassicETC $31.66 Ethereum-classic
# ArbitrumARB $1.68 Arbitrum
# MantleMNT $1.38 Mantle
# RenderRNDR $11.59 Render
# ImmutableIMX $2.99 Immutable-x
# OKBOKB $65.74 Okb
# OptimismOP $3.92 Optimism-ethereum
# CronosCRO $0.15 Cronos
# StellarXLM $0.14 Stellar
# HederaHBAR $0.12 Hedera
# The GraphGRT $0.41 The-graph
# BittensorTAO $569.67 Bittensor
# InjectiveINJ $38.91 Injective
# PepePEPE $0.00 Pepe
# VeChainVET $0.05 Vechain
# THORChainRUNE $9.53 Thorchain
# dogwifhatWIF $3.20 Dogwifhat
# KaspaKAS $0.13 Kaspa
# Theta NetworkTHETA $3.04 Theta-network
# FantomFTM $1.08 Fantom
# MakerMKR $3228.23 Maker
# Lido DAOLDO $3.14 Lido-dao
# Fetch.aiFET $3.30 Fetch
# ArweaveAR $41.39 Arweave
# First Digital USDFDUSD $1.00 First-digital-usd
# SuiSUI $2.07 Sui
# MoneroXMR $137.23 Monero
# CelestiaTIA $14.29 Celestia
# SeiSEI $0.87 Sei
# AlgorandALGO $0.28 Algorand
# FLOKIFLOKI $0.00 Floki-inu
# FlowFLOW $1.41 Flow
# GalaGALA $0.07 Gala
# BeamBEAM $0.04 Onbeam
# AaveAAVE $128.30 Aave
# ConfluxCFX $0.47 Conflux-network
# JupiterJUP $1.31 Jupiter-ag
# Bitcoin SVBSV $88.26 Bitcoin-sv
# SingularityNETAGIX $1.34 Singularitynet
# BonkBONK $0.00 Bonk1
# QuantQNT $139.16 Quant
# MultiversXEGLD $62.07 Multiversx-egld
# StarknetSTRK $2.26 Starknet-token
# dYdX (Native)DYDX $3.54 Dydx-chain
# SynthetixSNX $4.96 Synthetix
# Axie InfinityAXS $11.15 Axie-infinity
# The SandboxSAND $0.70 The-sandbox
# BitTorrent (New)BTT $0.00 Bittorrent-new
# WorldcoinWLD $8.86 Worldcoin-org
# Pyth NetworkPYTH $0.93 Pyth-network
# MinaMINA $1.28 Mina
# ORDIORDI $64.81 Ordi
# Bitget TokenBGB $0.96 Bitget-token-new
# TezosXTZ $1.38 Tezos
# FlareFLR $0.04 Flare
# ChilizCHZ $0.15 Chiliz
# RoninRON $4.24 Ronin
# DecentralandMANA $0.68 Decentraland
# eCashXEC $0.00 Ecash
# Akash NetworkAKT $5.38 Akash-network
# ApeCoinAPE $2.04 Apecoin-ape
# AxelarAXL $2.02 Axelar
# OndoONDO $0.88 Ondo-finance
# EOSEOS $1.07 Eos
# NeoNEO $16.04 Neo
# IOTAIOTA $0.35 Iota
# KuCoin TokenKCS $11.64 Kucoin-token
# KavaKAVA $1.01 Kava
# JasmyCoinJASMY $0.02 Jasmy
# PancakeSwapCAKE $4.38 Pancakeswap
# SATS1000SATS $0.00 Sats
# AIOZ NetworkAIOZ $0.98 Aioz-network
# dYdX (ethDYDX)ETHDYDX $3.55 Dydx-ethdydx

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="scrap"
)
cursor = conn.cursor()
cursor.execute('DROP TABLE IF EXISTS crypto_info')
cursor.execute('''
    CREATE TABLE IF NOT EXISTS crypto_info (
        id INT AUTO_INCREMENT PRIMARY KEY,
        name VARCHAR(255),
        price VARCHAR(255),
        market VARCHAR(255)
    )
''')

for crypto_name, price, crypto_market in filtered_elements:   
    cursor.execute('INSERT INTO crypto_info (name, price, market) VALUES (%s, %s, %s)', (crypto_name, price, crypto_market))

conn.commit()
conn.close()

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="",
    database="scrap"
)
cursor = conn.cursor()

cursor.execute('SELECT * FROM crypto_info')
rows = cursor.fetchall()

print("Table crypto_info:")
for row in rows:
    print(row)

conn.close()
# Out:
# Table crypto_info:
# (1, 'BitcoinBTC', '€64,834.19', '19,665,712 BTC')
# (2, 'EthereumETH', '€3,307.45', '120,073,215 ETH')
# (3, 'Tether USDtUSDT', '€0.9241', '104,362,092,744 USDT')
# (4, 'BNBBNB', '€533.74', '149,536,620 BNB')
# (5, 'SolanaSOL', '€172.58', '444,306,679 SOL')
# (6, 'XRPXRP', '€0.5741', '54,884,241,878 XRP')
# (7, 'USDCUSDC', '€0.9242', '32,287,299,828 USDC')
# (8, 'DogecoinDOGE', '€0.1738', '143,639,236,384 DOGE')
# (9, 'CardanoADA', '€0.6035', '35,578,756,687 ADA')
# (10, 'AvalancheAVAX', '€50.25', '377,416,536 AVAX')
# (11, 'Shiba InuSHIB', '$0.00', 'Shiba-inu')
# (12, 'ToncoinTON', '$5.04', 'Toncoin')
# (13, 'PolkadotDOT', '$9.59', 'Polkadot-new')
# (14, 'ChainlinkLINK', '$19.70', 'Chainlink')
# (15, 'TRONTRX', '$0.12', 'Tron')
# (16, 'PolygonMATIC', '$1.05', 'Polygon')
# (17, 'Bitcoin CashBCH', '$496.57', 'Bitcoin-cash')
# (18, 'Internet ComputerICP', '$19.48', 'Internet-computer')
# (19, 'NEAR ProtocolNEAR', '$7.73', 'Near-protocol')
# (20, 'UniswapUNI', '$12.48', 'Uniswap')
# (21, 'AptosAPT', '$18.22', 'Aptos')
# (22, 'LitecoinLTC', '$96.64', 'Litecoin')
# (23, 'UNUS SED LEOLEO', '$6.07', 'Unus-sed-leo')
# (24, 'DaiDAI', '$1.00', 'Multi-collateral-dai')
# (25, 'CosmosATOM', '$12.84', 'Cosmos')
# (26, 'StacksSTX', '$3.45', 'Stacks')
# (27, 'FilecoinFIL', '$9.36', 'Filecoin')
# (28, 'Ethereum ClassicETC', '$31.66', 'Ethereum-classic')
# (29, 'ArbitrumARB', '$1.68', 'Arbitrum')
# (30, 'MantleMNT', '$1.38', 'Mantle')
# (31, 'RenderRNDR', '$11.59', 'Render')
# (32, 'ImmutableIMX', '$2.99', 'Immutable-x')
# (33, 'OKBOKB', '$65.74', 'Okb')
# (34, 'OptimismOP', '$3.92', 'Optimism-ethereum')
# (35, 'CronosCRO', '$0.15', 'Cronos')
# (36, 'StellarXLM', '$0.14', 'Stellar')
# (37, 'HederaHBAR', '$0.12', 'Hedera')
# (38, 'The GraphGRT', '$0.41', 'The-graph')
# (39, 'BittensorTAO', '$569.67', 'Bittensor')
# (40, 'InjectiveINJ', '$38.91', 'Injective')
# (41, 'PepePEPE', '$0.00', 'Pepe')
# (42, 'VeChainVET', '$0.05', 'Vechain')
# (43, 'THORChainRUNE', '$9.53', 'Thorchain')
# (44, 'dogwifhatWIF', '$3.20', 'Dogwifhat')
# (45, 'KaspaKAS', '$0.13', 'Kaspa')
# (46, 'Theta NetworkTHETA', '$3.04', 'Theta-network')
# (47, 'FantomFTM', '$1.08', 'Fantom')
# (48, 'MakerMKR', '$3228.23', 'Maker')
# (49, 'Lido DAOLDO', '$3.14', 'Lido-dao')
# (50, 'Fetch.aiFET', '$3.30', 'Fetch')
# (51, 'ArweaveAR', '$41.39', 'Arweave')
# (52, 'First Digital USDFDUSD', '$1.00', 'First-digital-usd')
# (53, 'SuiSUI', '$2.07', 'Sui')
# (54, 'MoneroXMR', '$137.23', 'Monero')
# (55, 'CelestiaTIA', '$14.29', 'Celestia')
# (56, 'SeiSEI', '$0.87', 'Sei')
# (57, 'AlgorandALGO', '$0.28', 'Algorand')
# (58, 'FLOKIFLOKI', '$0.00', 'Floki-inu')
# (59, 'FlowFLOW', '$1.41', 'Flow')
# (60, 'GalaGALA', '$0.07', 'Gala')
# (61, 'BeamBEAM', '$0.04', 'Onbeam')
# (62, 'AaveAAVE', '$128.30', 'Aave')
# (63, 'ConfluxCFX', '$0.47', 'Conflux-network')
# (64, 'JupiterJUP', '$1.31', 'Jupiter-ag')
# (65, 'Bitcoin SVBSV', '$88.26', 'Bitcoin-sv')
# (66, 'SingularityNETAGIX', '$1.34', 'Singularitynet')
# (67, 'BonkBONK', '$0.00', 'Bonk1')
# (68, 'QuantQNT', '$139.16', 'Quant')
# (69, 'MultiversXEGLD', '$62.07', 'Multiversx-egld')
# (70, 'StarknetSTRK', '$2.26', 'Starknet-token')
# (71, 'dYdX (Native)DYDX', '$3.54', 'Dydx-chain')
# (72, 'SynthetixSNX', '$4.96', 'Synthetix')
# (73, 'Axie InfinityAXS', '$11.15', 'Axie-infinity')
# (74, 'The SandboxSAND', '$0.70', 'The-sandbox')
# (75, 'BitTorrent (New)BTT', '$0.00', 'Bittorrent-new')
# (76, 'WorldcoinWLD', '$8.86', 'Worldcoin-org')
# (77, 'Pyth NetworkPYTH', '$0.93', 'Pyth-network')
# (78, 'MinaMINA', '$1.28', 'Mina')
# (79, 'ORDIORDI', '$64.81', 'Ordi')
# (80, 'Bitget TokenBGB', '$0.96', 'Bitget-token-new')
# (81, 'TezosXTZ', '$1.38', 'Tezos')
# (82, 'FlareFLR', '$0.04', 'Flare')
# (83, 'ChilizCHZ', '$0.15', 'Chiliz')
# (84, 'RoninRON', '$4.24', 'Ronin')
# (85, 'DecentralandMANA', '$0.68', 'Decentraland')
# (86, 'eCashXEC', '$0.00', 'Ecash')
# (87, 'Akash NetworkAKT', '$5.38', 'Akash-network')
# (88, 'ApeCoinAPE', '$2.04', 'Apecoin-ape')
# (89, 'AxelarAXL', '$2.02', 'Axelar')
# (90, 'OndoONDO', '$0.88', 'Ondo-finance')
# (91, 'EOSEOS', '$1.07', 'Eos')
# (92, 'NeoNEO', '$16.04', 'Neo')
# (93, 'IOTAIOTA', '$0.35', 'Iota')
# (94, 'KuCoin TokenKCS', '$11.64', 'Kucoin-token')
# (95, 'KavaKAVA', '$1.01', 'Kava')
# (96, 'JasmyCoinJASMY', '$0.02', 'Jasmy')
# (97, 'PancakeSwapCAKE', '$4.38', 'Pancakeswap')
# (98, 'SATS1000SATS', '$0.00', 'Sats')
# (99, 'AIOZ NetworkAIOZ', '$0.98', 'Aioz-network')
# (100, 'dYdX (ethDYDX)ETHDYDX', '$3.55', 'Dydx-ethdydx')

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calcul du nombre total d'éléments
total_elements = len(filtered_elements)
print("Nombre total d'éléments :", total_elements)

# Examiner le format des prix des jetons et les convertir en dollars si nécessaire
prices = []
for element in filtered_elements:
    price_str = element[1].replace('$', '').replace(',', '')  # Suppression des symboles de devise et des virgules
    if '€' in price_str:  # Si le prix est en euros, le convertir en dollars
        price_str = str(float(price_str.replace('€', '')) * 1.18)  # Conversion en dollars à un taux de change approximatif
    prices.append(float(price_str))

print("Format des prix des jetons :", type(prices[0]))

# Tracer un graphique de dispersion pour visualiser la relation entre le rang et le prix du jeton
ranks = np.arange(1, total_elements + 1)
prices_sorted = sorted(prices, reverse=True)  # Trie des prix dans l'ordre décroissant pour le graphique

plt.figure(figsize=(10, 6))
plt.scatter(ranks, prices_sorted, color='blue', alpha=0.5)
plt.title('Relation entre le rang et le prix du jeton')
plt.xlabel('Rang (capitalisation boursière)')
plt.ylabel('Prix du jeton ($)')
plt.yscale('log')  # Échelle logarithmique pour mieux visualiser les données
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()
# Out:
# Nombre total d'éléments : 100
# Format des prix des jetons : <class 'float'>
